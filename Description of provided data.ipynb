# %% [markdown]
# The dataset 'CaseStudyData_2023.xlsx' encompasses multiple time series variables for upcoming analysis. This set comprises the 'Default Rate', designated as the primary variable, alongside various macroeconomic variables poised to serve as explanatory factors in the ensuing regression study.

# %%
import pandas as pd
import numpy as np
from scipy import stats

# Importing data from file 
dfCDR = pd.read_excel('CaseStudyData_2023-1.xlsx', sheet_name= 'Corporate Default Rate')

# %% [markdown]
# Commencing with the 'Default Rate', a table outlining summary statistics is presented below.

# %%
column = dfCDR.iloc[:, 1]
# Basic statistics
basic_stats = column.describe()

# Advanced statistics
advanced_stats = {
    'Skewness': column.skew(),
    'Kurtosis': column.kurtosis(),
    'Variance': column.var(),
    'Standard Error': column.sem(),
    '95% CI Lower': stats.norm.interval(0.95, loc=column.mean(), scale=column.sem())[0],
    '95% CI Upper': stats.norm.interval(0.95, loc=column.mean(), scale=column.sem())[1]
}

# Combining basic and advanced statistics
all_stats = {**basic_stats.to_dict(), **advanced_stats}

# Formatting as a DataFrame for display
stats_df = pd.DataFrame(list(all_stats.items()), columns=['Statistic', 'Value'])
stats_df.set_index('Statistic', inplace=True)

print(stats_df)
# Out:
#                     Value
# Statistic
# count           23.000000
# mean             1.585217
# std              1.088109
# min              0.370000
# 25%              0.820000
# 50%              1.210000
# 75%              2.010000
# max              4.190000
# Skewness         1.226986
# Kurtosis         0.575223
# Variance         1.183981
# Standard Error   0.226886
# 95% CI Lower     1.140528
# 95% CI Upper     2.029906

# %% [markdown]
# The above table presents the main statistics like mean, standard deviation, minimum and maximum, quartiles, skewness, kurtosis, variance, standard error and both confidence intervals. It is important to notice that this dataset contains only 23 values. The central tendency of the data is around 1.59, minimum is 0.37 and maximum is 4.19. Standard Deviation (1. 0881) value suggests a moderate level of variability or dispersion around the mean. A standard deviation of about 1.09 indicates that, on average, the data points differ from the mean by this amount. A kurtosis value relatively far from 0 suggests that the data distribution has a shape somewhat unsimilar to a normal distribution in terms of its tails.
#
# This positive skewness (1.2270) indicates that Default Rate dataset has a right-skewed distribution. In other words, there's a longer tail on the right side of the distribution, with more data points located on the lower value side. Which can be easily seen on the Figure 1 below.

# %%
import matplotlib.pyplot as plt
import seaborn as sns


# Plotting the distribution of the variables in the column
plt.figure(figsize=(10, 10))
sns.histplot(column, kde=True, bins=5)

plt.title('Figure 1. Distribution of Corporate Default Rate')
plt.xlabel('Percentage')
plt.ylabel('Frequency')
plt.grid(False)
plt.show()

# %% [markdown]
# Overall, these statistics suggest a dataset with moderate variability, a tendency to have values clustered around a mean of 1.59, and a right-skewed distribution. The confidence interval indicates a high probability range for the true mean of the underlying population.

# %% [markdown]
# The Table 2 below shows the summary statistics of the data provided in the dataset and called historic data – macroeconomic variables which will be used further in model. The statistics presented below are mean, standard deviation, minimum, maximum and median value, as well as skewness, kurtosis, variance and standard error. It is important to notice that this dataset contains only 23 values. By looking at the skewness statistic it is possible to say that variables are relatively distributed close to the middle with the exception of GDP growth rate and CPI rate. This might be observed on the presented below plots of the distribution of data. All variables with the exception of EURIBOR 3-month,
# GDP growth rate and Yield structure are positive and their minimum value doesn’t reach negative numbers.

# %%
# Importing data from file 
dfHD = pd.read_excel('CaseStudyData_2023-1.xlsx', sheet_name= 'Historic Data')
Nofirstcol = dfHD.iloc[:, 1:]

basic_stats1 = Nofirstcol.describe()
basic_stats1
# Out:
#        Labor Markets: Unemployment rate, (%, SA)  \
# count                                  23.000000
# mean                                    9.498601
# std                                     1.490999
# min                                     6.700000
# 25%                                     8.552944
# 50%                                     9.363484
# 75%                                    10.512047
# max                                    12.482158
#
#        Consumer Price Index: EU Harmonized - Total, (Index 2015=100, SA)  \
# count                                          23.000000
# mean                                           94.151362
# std                                            10.764756
# min                                            75.807483
# 25%                                            85.599449
# 50%                                            95.667533
# 75%                                           101.004272
# max                                           116.835875
#
#        National Accounts: Real Gross Domestic Product [GDP] - Market exchange rate, (Bil. 2012 USD, CDASAAR)  \
# count                                          23.000000
# mean                                        12733.707140
# std                                           892.650083
# min                                         11155.393303
# 25%                                         12166.846600
# 50%                                         12757.556053
# 75%                                         13247.998237
# max                                         14365.524324
#
#        Interest Rate: EURIBOR - 3-Month, (% p.a., NSA)  \
# count                                        23.000000
# mean                                          1.439432
# std                                           1.786991
# min                                          -0.548767
# 25%                                          -0.141529
# 50%                                           0.810958
# 75%                                           2.706346
# max                                           4.634233
#
#        Interest Rates: Central government bond yield curve - All bond ratings total - Spot rate - 10 year maturity, (% p.a., NSA)  \
# count                                          23.000000
# mean                                            2.917446
# std                                             1.720984
# min                                             0.083607
# 25%                                             1.187993
# 50%                                             3.650546
# 75%                                             4.217056
# max                                             5.438877
#
#        GDP growth rate  Yield Structure, long-term - short-term (%)  \
# count        22.000000                                    23.000000
# mean          0.011876                                     1.478014
# std           0.025444                                     0.945489
# min          -0.065798                                    -0.264527
# 25%           0.007901                                     0.767470
# 50%           0.018004                                     1.440000
# 75%           0.021796                                     1.962411
# max           0.052563                                     3.077363
#
#         CPI rate  Unemployment rate
# count  22.000000          23.000000
# mean    0.019988           0.094986
# std     0.016952           0.014910
# min     0.001901           0.067000
# 25%     0.012431           0.085529
# 50%     0.021431           0.093635
# 75%     0.023778           0.105120
# max     0.084000           0.124822

# %%
advanced_stats1 = {
    'Skewness': Nofirstcol.skew(),
    'Kurtosis': Nofirstcol.kurtosis(),
    'Variance': Nofirstcol.var(),
    'Standard Error': Nofirstcol.sem(),
    '95% CI Lower': stats.norm.interval(0.95, loc=Nofirstcol.mean(), scale=Nofirstcol.sem())[0],
    '95% CI Upper': stats.norm.interval(0.95, loc=Nofirstcol.mean(), scale=Nofirstcol.sem())[1]
}
adv_result = pd.DataFrame(advanced_stats1)
adv_result

summarised_stats = pd.concat([basic_stats1.T, adv_result],axis=1)
summarised_stats
# Out:
#                                                     count          mean  \
# Labor Markets: Unemployment rate, (%, SA)            23.0      9.498601
# Consumer Price Index: EU Harmonized - Total, (I...   23.0     94.151362
# National Accounts: Real Gross Domestic Product ...   23.0  12733.707140
# Interest Rate: EURIBOR - 3-Month, (% p.a., NSA)      23.0      1.439432
# Interest Rates: Central government bond yield c...   23.0      2.917446
# GDP growth rate                                      22.0      0.011876
# Yield Structure, long-term - short-term (%)          23.0      1.478014
# CPI rate                                             22.0      0.019988
# Unemployment rate                                    23.0      0.094986
#
#                                                            std           min  \
# Labor Markets: Unemployment rate, (%, SA)             1.490999      6.700000
# Consumer Price Index: EU Harmonized - Total, (I...   10.764756     75.807483
# National Accounts: Real Gross Domestic Product ...  892.650083  11155.393303
# Interest Rate: EURIBOR - 3-Month, (% p.a., NSA)       1.786991     -0.548767
# Interest Rates: Central government bond yield c...    1.720984      0.083607
# GDP growth rate                                       0.025444     -0.065798
# Yield Structure, long-term - short-term (%)           0.945489     -0.264527
# CPI rate                                              0.016952      0.001901
# Unemployment rate                                     0.014910      0.067000
#
#                                                              25%  \
# Labor Markets: Unemployment rate, (%, SA)               8.552944
# Consumer Price Index: EU Harmonized - Total, (I...     85.599449
# National Accounts: Real Gross Domestic Product ...  12166.846600
# Interest Rate: EURIBOR - 3-Month, (% p.a., NSA)        -0.141529
# Interest Rates: Central government bond yield c...      1.187993
# GDP growth rate                                         0.007901
# Yield Structure, long-term - short-term (%)             0.767470
# CPI rate                                                0.012431
# Unemployment rate                                       0.085529
#
#                                                              50%  \
# Labor Markets: Unemployment rate, (%, SA)               9.363484
# Consumer Price Index: EU Harmonized - Total, (I...     95.667533
# National Accounts: Real Gross Domestic Product ...  12757.556053
# Interest Rate: EURIBOR - 3-Month, (% p.a., NSA)         0.810958
# Interest Rates: Central government bond yield c...      3.650546
# GDP growth rate                                         0.018004
# Yield Structure, long-term - short-term (%)             1.440000
# CPI rate                                                0.021431
# Unemployment rate                                       0.093635
#
#                                                              75%  \
# Labor Markets: Unemployment rate, (%, SA)              10.512047
# Consumer Price Index: EU Harmonized - Total, (I...    101.004272
# National Accounts: Real Gross Domestic Product ...  13247.998237
# Interest Rate: EURIBOR - 3-Month, (% p.a., NSA)         2.706346
# Interest Rates: Central government bond yield c...      4.217056
# GDP growth rate                                         0.021796
# Yield Structure, long-term - short-term (%)             1.962411
# CPI rate                                                0.023778
# Unemployment rate                                       0.105120
#
#                                                              max  Skewness  \
# Labor Markets: Unemployment rate, (%, SA)              12.482158  0.382171
# Consumer Price Index: EU Harmonized - Total, (I...    116.835875 -0.011156
# National Accounts: Real Gross Domestic Product ...  14365.524324  0.042609
# Interest Rate: EURIBOR - 3-Month, (% p.a., NSA)         4.634233  0.620387
# Interest Rates: Central government bond yield c...      5.438877 -0.389848
# GDP growth rate                                         0.052563 -1.780952
# Yield Structure, long-term - short-term (%)             3.077363  0.213368
# CPI rate                                                0.084000  2.574823
# Unemployment rate                                       0.124822  0.382171
#
#                                                     Kurtosis       Variance  \
# Labor Markets: Unemployment rate, (%, SA)          -0.329508       2.223077
# Consumer Price Index: EU Harmonized - Total, (I... -0.630539     115.879970
# National Accounts: Real Gross Domestic Product ... -0.665816  796824.170501
# Interest Rate: EURIBOR - 3-Month, (% p.a., NSA)    -1.076173       3.193338
# Interest Rates: Central government bond yield c... -1.326797       2.961786
# GDP growth rate                                     4.128976       0.000647
# Yield Structure, long-term - short-term (%)        -0.657837       0.893950
# CPI rate                                            9.777323       0.000287
# Unemployment rate                                  -0.329508       0.000222
#
#                                                     Standard Error  \
# Labor Markets: Unemployment rate, (%, SA)                 0.310895
# Consumer Price Index: EU Harmonized - Total, (I...        2.244607
# National Accounts: Real Gross Domestic Product ...      186.130409
# Interest Rate: EURIBOR - 3-Month, (% p.a., NSA)           0.372613
# Interest Rates: Central government bond yield c...        0.358850
# GDP growth rate                                           0.005425
# Yield Structure, long-term - short-term (%)               0.197148
# CPI rate                                                  0.003614
# Unemployment rate                                         0.003109
#
#                                                     95% CI Lower  95% CI Upper
# Labor Markets: Unemployment rate, (%, SA)               8.889259     10.107944
# Consumer Price Index: EU Harmonized - Total, (I...     89.752013     98.550710
# National Accounts: Real Gross Domestic Product ...  12368.898242  13098.516039
# Interest Rate: EURIBOR - 3-Month, (% p.a., NSA)         0.709123      2.169740
# Interest Rates: Central government bond yield c...      2.214113      3.620779
# GDP growth rate                                         0.001244      0.022509
# Yield Structure, long-term - short-term (%)             1.091611      1.864417
# CPI rate                                                0.012905      0.027072
# Unemployment rate                                       0.088893      0.101079

# %%
# Creating a plot for each data 
for i in range(1,9):
    plt.figure(figsize=(10, 10))
    sns.histplot(Nofirstcol.iloc[:,i], kde=True, bins=6)
    # plt.hist(Nofirstcol.iloc[:,0], weights=np.ones(len(Nofirstcol.iloc[:,0])) / len(Nofirstcol.iloc[:,0]))

    plt.ylim([0,12.5])
    plt.title(Nofirstcol.columns[i])
    plt.xlabel('Percentage')
    plt.ylabel('Frequency')
    plt.grid(False)
    plt.show()

# %% [markdown]
# The table presented below shows the matrix of correlations between variables. It can be observed that there is a strong positive correlation between variables Real Gross Domestic Product and Consumer Price Index, as well as for Central Government bond yield curve and EURIBOR – 3 month. Rather strong negative correlation can be observed for the EURIBOR – 3 month and Consumer Price Index, also for the Central Government bond yield curve with Consumer Price Index and with Real Gross Domestic Product. Other variables tends to be no significantly correlated or both low positively and negatively correlated. This results can be graphically observed on the presented below Figure 3. The more narrower the cycles the stronger the positive correlation, the farer the figures are from smooth oval – the stronger the negative correlation.

# %%
Nofirstcol.columns = ['tobedeleted',
                      'Consumer Price Index',
                      'Real Gross Domestic Product',
                      'EURIBOR - 3-Month',
                      'Central government bond yield curve ',
                      'GDP growth rate',
                      'Yield Structure',
                      'CPI rate',
                      'Unemployment rate',]


Corr_df = Nofirstcol.loc[:,['Unemployment rate',
                'Consumer Price Index',
                'Real Gross Domestic Product',
                'EURIBOR - 3-Month',
                'Central government bond yield curve ',
                'Yield Structure']]


Corr_df.corr(method='pearson').to_clipboard()
Corr_matrix = Corr_df.corr(method='pearson')

Corr_matrix
# Out:
#                                       Unemployment rate  Consumer Price Index  \
# Unemployment rate                              1.000000             -0.036225
# Consumer Price Index                          -0.036225              1.000000
# Real Gross Domestic Product                   -0.240640              0.941045
# EURIBOR - 3-Month                             -0.307894             -0.823118
# Central government bond yield curve            0.053335             -0.839112
# Yield Structure                                0.679006              0.028352
#
#                                       Real Gross Domestic Product  \
# Unemployment rate                                       -0.240640
# Consumer Price Index                                     0.941045
# Real Gross Domestic Product                              1.000000
# EURIBOR - 3-Month                                       -0.710134
# Central government bond yield curve                     -0.834536
# Yield Structure                                         -0.176861
#
#                                       EURIBOR - 3-Month  \
# Unemployment rate                             -0.307894
# Consumer Price Index                          -0.823118
# Real Gross Domestic Product                   -0.710134
# EURIBOR - 3-Month                              1.000000
# Central government bond yield curve            0.855369
# Yield Structure                               -0.333071
#
#                                       Central government bond yield curve   \
# Unemployment rate                                                 0.053335
# Consumer Price Index                                             -0.839112
# Real Gross Domestic Product                                      -0.834536
# EURIBOR - 3-Month                                                 0.855369
# Central government bond yield curve                               1.000000
# Yield Structure                                                   0.203543
#
#                                       Yield Structure
# Unemployment rate                            0.679006
# Consumer Price Index                         0.028352
# Real Gross Domestic Product                 -0.176861
# EURIBOR - 3-Month                           -0.333071
# Central government bond yield curve          0.203543
# Yield Structure                              1.000000

# %%
g = sns.pairplot(Corr_df, diag_kind="kde")
g.map(sns.kdeplot, levels=4, color=".2")
# Out:
# c:\Users\mateu\OneDrive\Pulpit\pythonnn\CS1-env\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: KDE cannot be estimated (0 variance or perfect covariance). Pass `warn_singular=False` to disable this warning.
#   func(x=x, y=y, **kwargs)
# c:\Users\mateu\OneDrive\Pulpit\pythonnn\CS1-env\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: KDE cannot be estimated (0 variance or perfect covariance). Pass `warn_singular=False` to disable this warning.
#   func(x=x, y=y, **kwargs)
# c:\Users\mateu\OneDrive\Pulpit\pythonnn\CS1-env\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: KDE cannot be estimated (0 variance or perfect covariance). Pass `warn_singular=False` to disable this warning.
#   func(x=x, y=y, **kwargs)
# c:\Users\mateu\OneDrive\Pulpit\pythonnn\CS1-env\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: KDE cannot be estimated (0 variance or perfect covariance). Pass `warn_singular=False` to disable this warning.
#   func(x=x, y=y, **kwargs)
